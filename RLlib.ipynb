# %%
# !pip install ray[rllib]
# Out:
# Collecting ray[rllib]
#   Downloading https://files.pythonhosted.org/packages/ed/83/59ddfbd982626f5fa58f0ab9ea201757b1ccc34ba3b3bdf44a61a3a7d8b1/ray-0.7.6-cp36-cp36m-manylinux1_x86_64.whl (75.8MB)
#      |████████████████████████████████| 75.8MB 105kB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Collecting redis>=3.3.2
#   Downloading https://files.pythonhosted.org/packages/32/ae/28613a62eea0d53d3db3147f8715f90da07667e99baeedf1010eb400f8c0/redis-3.3.11-py2.py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 8.9MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.12)
# Collecting funcsigs
#   Downloading https://files.pythonhosted.org/packages/69/cb/f5be453359271714c01b9bd06126eaf2e368f1fddfff30818754b5ac2328/funcsigs-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.13)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (7.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.6.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.6.4)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.17.4)
# Requirement already satisfied: scipy; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.3.2)
# Collecting lz4; extra == "rllib"
#   Downloading https://files.pythonhosted.org/packages/5d/5e/cedd32c203ce0303188b0c7ff8388bba3c33e4bf6da21ae789962c4fb2e7/lz4-2.2.1-cp36-cp36m-manylinux1_x86_64.whl (395kB)
#      |████████████████████████████████| 399kB 43.8MB/s
# Requirement already satisfied: gym[atari]; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.15.4)
# Collecting opencv-python-headless; extra == "rllib"
#   Downloading https://files.pythonhosted.org/packages/5d/96/b2824df85d8c5f148125e4fee073a62fde17639502fe67042b212ebfe488/opencv_python_headless-4.1.2.30-cp36-cp36m-manylinux1_x86_64.whl (21.8MB)
#      |████████████████████████████████| 21.8MB 411kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[rllib]) (41.6.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (7.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (1.3.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (1.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->ray[rllib]) (19.3.0)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.3.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (3.4.7.28)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.2.2)
# Requirement already satisfied: atari-py~=0.2.0; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (0.2.6)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (4.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.3.2,>=1.2.0->gym[atari]; extra == "rllib"->ray[rllib]) (0.16.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow; extra == "atari"->gym[atari]; extra == "rllib"->ray[rllib]) (0.46)
# Installing collected packages: colorama, redis, funcsigs, lz4, opencv-python-headless, ray
# Successfully installed colorama-0.4.1 funcsigs-1.0.2 lz4-2.2.1 opencv-python-headless-4.1.2.30 ray-0.7.6 redis-3.3.11

# %%
# !rllib train --env=SpaceInvaders-v0 \
    --run=DQN --config '{"num_atoms": 51,\
    "double_q": true,\
    "dueling": true,\
    "noisy": true,\
    "monitor":true,\
    "gamma": 0.99,\
    "lr": 0.0001,\
    "hiddens": [512],\
    "learning_starts": 10000,\
    "buffer_size": 50000,\
    "sample_batch_size": 4,\
    "train_batch_size": 32,\
    "schedule_max_timesteps": 2000000,\
    "exploration_final_eps": 0,\
    "exploration_fraction": 0.000001,\
    "target_network_update_freq": 500,\
    "prioritized_replay": true,\
    "prioritized_replay_alpha": 0.5,\
    "beta_annealing_fraction": 0.2,\
    "final_prioritized_replay_beta": 1,\
    "n_step": 3,\
    "num_gpus": 1\
    }'
# Out:
# 2019-11-30 12:39:14,773	WARNING worker.py:1268 -- WARNING: Not updating worker name since `setproctitle` is not installed. Install this with `pip install setproctitle` (or ray[debug]) to enable monitoring of worker processes.
# 2019-11-30 12:39:14,775	INFO resource_spec.py:205 -- Starting Ray with 5.42 GiB memory available for workers and up to 2.72 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 1.1/12.7 GiB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 1.1/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING
#
# (pid=877) 2019-11-30 12:39:20,576	INFO trainer.py:345 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=877) 2019-11-30 12:39:30,693	INFO rollout_worker.py:768 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.DQNTFPolicy object at 0x7f111f984d30>}
# (pid=877) 2019-11-30 12:39:30,693	INFO rollout_worker.py:769 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f111f984ac8>}
# (pid=877) 2019-11-30 12:39:30,693	INFO rollout_worker.py:370 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f107d5b25f8>}
# (pid=877) 2019-11-30 12:39:30,697	INFO trainable.py:102 -- _setup took 10.121 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=877) 2019-11-30 12:39:30,749	INFO rollout_worker.py:467 -- Generating sample batch of size 4
# (pid=877) 2019-11-30 12:39:30,972	INFO sampler.py:310 -- Raw obs from env: { 0: { 'agent0': np.ndarray((84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.476)}}
# (pid=877) 2019-11-30 12:39:30,972	INFO sampler.py:311 -- Info return from env: {0: {'agent0': None}}
# (pid=877) 2019-11-30 12:39:30,972	INFO sampler.py:409 -- Preprocessed obs: np.ndarray((84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.476)
# (pid=877) 2019-11-30 12:39:30,973	INFO sampler.py:413 -- Filtered obs: np.ndarray((84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.476)
# (pid=877) 2019-11-30 12:39:30,973	INFO sampler.py:528 -- Inputs to compute_actions():
# (pid=877)
# (pid=877) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=877)                                   'env_id': 0,
# (pid=877)                                   'info': None,
# (pid=877)                                   'obs': np.ndarray((84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.476),
# (pid=877)                                   'prev_action': np.ndarray((), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=877)                                   'prev_reward': 0.0,
# (pid=877)                                   'rnn_state': []},
# (pid=877)                         'type': 'PolicyEvalData'}]}
# (pid=877)
# (pid=877) 2019-11-30 12:39:30,974	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=877) 2019-11-30 12:39:31,060	INFO sampler.py:555 -- Outputs of compute_actions():
# (pid=877)
# (pid=877) { 'default_policy': ( np.ndarray((1,), dtype=int64, min=1.0, max=1.0, mean=1.0),
# (pid=877)                       [],
# (pid=877)                       { 'q_values': np.ndarray((1, 6), dtype=float32, min=-1.093, max=0.819, mean=-0.102)})}
# (pid=877)
# (pid=877) 2019-11-30 12:39:31,078	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=877)
# (pid=877) { 'agent0': { 'data': { 'actions': np.ndarray((4,), dtype=int64, min=0.0, max=4.0, mean=2.25),
# (pid=877)                         'agent_index': np.ndarray((4,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=877)                         'dones': np.ndarray((4,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=877)                         'eps_id': np.ndarray((4,), dtype=int64, min=1206689881.0, max=1206689881.0, mean=1206689881.0),
# (pid=877)                         'infos': np.ndarray((4,), dtype=object, head={'ale.lives': 3}),
# (pid=877)                         'new_obs': np.ndarray((4, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.412),
# (pid=877)                         'obs': np.ndarray((4, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.452),
# (pid=877)                         'prev_actions': np.ndarray((4,), dtype=int64, min=0.0, max=4.0, mean=1.25),
# (pid=877)                         'prev_rewards': np.ndarray((4,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=877)                         'q_values': np.ndarray((4, 6), dtype=float32, min=-1.101, max=1.163, mean=0.171),
# (pid=877)                         'rewards': np.ndarray((4,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=877)                         't': np.ndarray((4,), dtype=int64, min=0.0, max=3.0, mean=1.5),
# (pid=877)                         'unroll_id': np.ndarray((4,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=877)                         'weights': np.ndarray((4,), dtype=float32, min=1.0, max=1.0, mean=1.0)},
# (pid=877)               'type': 'SampleBatch'}}
# (pid=877)
# (pid=877) 2019-11-30 12:39:31,080	INFO rollout_worker.py:501 -- Completed sample batch:
# (pid=877)
# (pid=877) { 'data': { 'actions': np.ndarray((4,), dtype=int64, min=0.0, max=4.0, mean=2.25),
# (pid=877)             'agent_index': np.ndarray((4,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=877)             'dones': np.ndarray((4,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=877)             'eps_id': np.ndarray((4,), dtype=int64, min=1206689881.0, max=1206689881.0, mean=1206689881.0),
# (pid=877)             'infos': np.ndarray((4,), dtype=object, head={'ale.lives': 3}),
# (pid=877)             'new_obs': np.ndarray((4, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.412),
# (pid=877)             'obs': np.ndarray((4, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=13.452),
# (pid=877)             'prev_actions': np.ndarray((4,), dtype=int64, min=0.0, max=4.0, mean=1.25),
# (pid=877)             'prev_rewards': np.ndarray((4,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=877)             'q_values': np.ndarray((4, 6), dtype=float32, min=-1.101, max=1.163, mean=0.171),
# (pid=877)             'rewards': np.ndarray((4,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=877)             't': np.ndarray((4,), dtype=int64, min=0.0, max=3.0, mean=1.5),
# (pid=877)             'unroll_id': np.ndarray((4,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=877)             'weights': np.ndarray((4,), dtype=float32, min=1.0, max=1.0, mean=1.0)},
# (pid=877)   'type': 'SampleBatch'}
# (pid=877)
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-39-35
#   done: false
#   episode_len_mean: .nan
#   episode_reward_max: .nan
#   episode_reward_mean: .nan
#   episode_reward_min: .nan
#   episodes_this_iter: 0
#   episodes_total: 0
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: .nan
#     learner: {}
#     max_exploration: 1.0
#     min_exploration: 1.0
#     num_steps_sampled: 1000
#     num_steps_trained: 0
#     num_target_updates: 1
#     opt_peak_throughput: 0.0
#     opt_samples: .nan
#     replay_time_ms: .nan
#     sample_time_ms: 16.005
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf: {}
#   time_since_restore: 5.20027494430542
#   time_this_iter_s: 5.20027494430542
#   time_total_s: 5.20027494430542
#   timestamp: 1575117575
#   timesteps_since_restore: 1000
#   timesteps_this_iter: 1000
#   timesteps_total: 1000
#   training_iteration: 1
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.2/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 5 s, 1 iter, 1000 ts, nan rew
#
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
# (pid=877)   out=out, **kwargs)
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=877)   ret = ret.dtype.type(ret / rcount)
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-39-44
#   done: false
#   episode_len_mean: 811.6666666666666
#   episode_reward_max: 540.0
#   episode_reward_mean: 251.66666666666666
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 3
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: .nan
#     learner: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 3000
#     num_steps_trained: 0
#     num_target_updates: 5
#     opt_peak_throughput: 0.0
#     opt_samples: .nan
#     replay_time_ms: .nan
#     sample_time_ms: 15.257
#     update_time_ms: 0.002
#   iterations_since_restore: 3
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.3136074483178648
#     mean_inference_ms: 2.3155619719011598
#     mean_processing_ms: 0.3946845103821494
#   time_since_restore: 13.78312635421753
#   time_this_iter_s: 4.464298963546753
#   time_total_s: 13.78312635421753
#   timestamp: 1575117584
#   timesteps_since_restore: 3000
#   timesteps_this_iter: 1000
#   timesteps_total: 3000
#   training_iteration: 3
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.2/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 13 s, 3 iter, 3000 ts, 252 rew
#
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
# (pid=877)   out=out, **kwargs)
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=877)   ret = ret.dtype.type(ret / rcount)
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-39-52
#   done: false
#   episode_len_mean: 896.0
#   episode_reward_max: 540.0
#   episode_reward_mean: 238.0
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 5
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: .nan
#     learner: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 5000
#     num_steps_trained: 0
#     num_target_updates: 9
#     opt_peak_throughput: 0.0
#     opt_samples: .nan
#     replay_time_ms: .nan
#     sample_time_ms: 15.104
#     update_time_ms: 0.002
#   iterations_since_restore: 5
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.267056956484431
#     mean_inference_ms: 2.299323719158688
#     mean_processing_ms: 0.369552064146671
#   time_since_restore: 22.05628275871277
#   time_this_iter_s: 4.187982797622681
#   time_total_s: 22.05628275871277
#   timestamp: 1575117592
#   timesteps_since_restore: 5000
#   timesteps_this_iter: 1000
#   timesteps_total: 5000
#   training_iteration: 5
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 22 s, 5 iter, 5000 ts, 238 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-01
#   done: false
#   episode_len_mean: 834.0
#   episode_reward_max: 540.0
#   episode_reward_mean: 213.125
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 8
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: .nan
#     learner: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 7000
#     num_steps_trained: 0
#     num_target_updates: 13
#     opt_peak_throughput: 0.0
#     opt_samples: .nan
#     replay_time_ms: .nan
#     sample_time_ms: 15.953
#     update_time_ms: 0.002
#   iterations_since_restore: 7
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.2289041636618534
#     mean_inference_ms: 2.2845546496977294
#     mean_processing_ms: 0.34607957744457285
#   time_since_restore: 30.349560260772705
#   time_this_iter_s: 4.151820182800293
#   time_total_s: 30.349560260772705
#   timestamp: 1575117601
#   timesteps_since_restore: 7000
#   timesteps_this_iter: 1000
#   timesteps_total: 7000
#   training_iteration: 7
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 30 s, 7 iter, 7000 ts, 213 rew
#
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
# (pid=877)   out=out, **kwargs)
# (pid=877) /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=877)   ret = ret.dtype.type(ret / rcount)
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-10
#   done: false
#   episode_len_mean: 823.2727272727273
#   episode_reward_max: 540.0
#   episode_reward_mean: 190.45454545454547
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 11
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: .nan
#     learner: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 9000
#     num_steps_trained: 0
#     num_target_updates: 17
#     opt_peak_throughput: 0.0
#     opt_samples: .nan
#     replay_time_ms: .nan
#     sample_time_ms: 15.43
#     update_time_ms: 0.002
#   iterations_since_restore: 9
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.2116084661380733
#     mean_inference_ms: 2.2771210866793026
#     mean_processing_ms: 0.3384693842834165
#   time_since_restore: 39.25127196311951
#   time_this_iter_s: 4.194396734237671
#   time_total_s: 39.25127196311951
#   timestamp: 1575117610
#   timesteps_since_restore: 9000
#   timesteps_this_iter: 1000
#   timesteps_total: 9000
#   training_iteration: 9
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 39 s, 9 iter, 9000 ts, 190 rew
#
# (pid=877) 2019-11-30 12:40:14,250	INFO rollout_worker.py:591 -- Training on concatenated sample batches:
# (pid=877)
# (pid=877) { 'count': 32,
# (pid=877)   'policy_batches': { 'default_policy': { 'data': { 'actions': np.ndarray((32,), dtype=int64, min=0.0, max=5.0, mean=2.406),
# (pid=877)                                                     'batch_indexes': np.ndarray((32,), dtype=int64, min=2.0, max=9695.0, mean=4376.156),
# (pid=877)                                                     'dones': np.ndarray((32,), dtype=bool, min=0.0, max=0.0, mean=0.0),
# (pid=877)                                                     'new_obs': np.ndarray((32, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=12.103),
# (pid=877)                                                     'obs': np.ndarray((32, 84, 84, 4), dtype=uint8, min=0.0, max=133.0, mean=12.118),
# (pid=877)                                                     'rewards': np.ndarray((32,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=877)                                                     'weights': np.ndarray((32,), dtype=float64, min=1.0, max=1.0, mean=1.0)},
# (pid=877)                                           'type': 'SampleBatch'}},
# (pid=877)   'type': 'MultiAgentBatch'}
# (pid=877)
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_1/kernel:0' shape=(28224, 256) dtype=float32>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_1/bias:0' shape=(256,) dtype=float32>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_out/kernel:0' shape=(256, 256) dtype=float32>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/fc_out/bias:0' shape=(256,) dtype=float32>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/hidden_0_sigma_w:0' shape=(256, 512) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/hidden_0_sigma_b:0' shape=(512,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/hidden_0_fc_w:0' shape=(256, 512) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,250	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/hidden_0_fc_b:0' shape=(512,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/output_sigma_w:0' shape=(512, 306) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/output_sigma_b:0' shape=(306,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/output_fc_w:0' shape=(512, 306) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/action_value/output_fc_b:0' shape=(306,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_hidden_0_sigma_w:0' shape=(256, 512) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_hidden_0_sigma_b:0' shape=(512,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_hidden_0_fc_w:0' shape=(256, 512) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_hidden_0_fc_b:0' shape=(512,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_output_sigma_w:0' shape=(512, 51) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_output_sigma_b:0' shape=(51,) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_output_fc_w:0' shape=(512, 51) dtype=float32_ref>
# (pid=877) 2019-11-30 12:40:14,251	INFO tf_policy.py:358 -- Optimizing variable <tf.Variable 'default_policy/q_func/state_value/dueling_output_fc_b:0' shape=(51,) dtype=float32_ref>
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-23
#   done: false
#   episode_len_mean: 826.1538461538462
#   episode_reward_max: 540.0
#   episode_reward_mean: 186.15384615384616
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 13
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.711
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.8483781814575195
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 11000
#     num_steps_trained: 8000
#     num_target_updates: 21
#     opt_peak_throughput: 2175.271
#     opt_samples: 32.0
#     replay_time_ms: 5.888
#     sample_time_ms: 15.233
#     update_time_ms: 0.008
#   iterations_since_restore: 11
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.2015973816488363
#     mean_inference_ms: 2.272756139865723
#     mean_processing_ms: 0.3321732450926595
#   time_since_restore: 53.17267656326294
#   time_this_iter_s: 9.771737098693848
#   time_total_s: 53.17267656326294
#   timestamp: 1575117623
#   timesteps_since_restore: 11000
#   timesteps_this_iter: 1000
#   timesteps_total: 11000
#   training_iteration: 11
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 53 s, 11 iter, 11000 ts, 186 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-33
#   done: false
#   episode_len_mean: 844.5
#   episode_reward_max: 540.0
#   episode_reward_mean: 192.85714285714286
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 14
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.143
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.859921932220459
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 12000
#     num_steps_trained: 16000
#     num_target_updates: 23
#     opt_peak_throughput: 2262.609
#     opt_samples: 32.0
#     replay_time_ms: 5.945
#     sample_time_ms: 15.822
#     update_time_ms: 0.004
#   iterations_since_restore: 12
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1972251360416395
#     mean_inference_ms: 2.270795738080301
#     mean_processing_ms: 0.32925440040516823
#   time_since_restore: 62.438039779663086
#   time_this_iter_s: 9.265363216400146
#   time_total_s: 62.438039779663086
#   timestamp: 1575117633
#   timesteps_since_restore: 12000
#   timesteps_this_iter: 1000
#   timesteps_total: 12000
#   training_iteration: 12
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 62 s, 12 iter, 12000 ts, 193 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-42
#   done: false
#   episode_len_mean: 811.5625
#   episode_reward_max: 540.0
#   episode_reward_mean: 180.9375
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 16
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.533
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.804290771484375
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 13000
#     num_steps_trained: 24000
#     num_target_updates: 25
#     opt_peak_throughput: 2201.857
#     opt_samples: 32.0
#     replay_time_ms: 5.96
#     sample_time_ms: 15.115
#     update_time_ms: 0.002
#   iterations_since_restore: 13
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.189489596491727
#     mean_inference_ms: 2.2672821177988847
#     mean_processing_ms: 0.32406603493501274
#   time_since_restore: 71.81156492233276
#   time_this_iter_s: 9.373525142669678
#   time_total_s: 71.81156492233276
#   timestamp: 1575117642
#   timesteps_since_restore: 13000
#   timesteps_this_iter: 1000
#   timesteps_total: 13000
#   training_iteration: 13
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 71 s, 13 iter, 13000 ts, 181 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-40-52
#   done: false
#   episode_len_mean: 810.8235294117648
#   episode_reward_max: 540.0
#   episode_reward_mean: 180.88235294117646
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 17
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.434
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.7493293285369873
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 14000
#     num_steps_trained: 32000
#     num_target_updates: 27
#     opt_peak_throughput: 2217.013
#     opt_samples: 32.0
#     replay_time_ms: 6.056
#     sample_time_ms: 15.33
#     update_time_ms: 0.002
#   iterations_since_restore: 14
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1860651378261675
#     mean_inference_ms: 2.26584234166757
#     mean_processing_ms: 0.32178073794307926
#   time_since_restore: 81.24642395973206
#   time_this_iter_s: 9.434859037399292
#   time_total_s: 81.24642395973206
#   timestamp: 1575117652
#   timesteps_since_restore: 14000
#   timesteps_this_iter: 1000
#   timesteps_total: 14000
#   training_iteration: 14
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 81 s, 14 iter, 14000 ts, 181 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-01
#   done: false
#   episode_len_mean: 808.7368421052631
#   episode_reward_max: 540.0
#   episode_reward_mean: 178.42105263157896
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 19
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.451
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.7337515354156494
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 15000
#     num_steps_trained: 40000
#     num_target_updates: 29
#     opt_peak_throughput: 2214.328
#     opt_samples: 32.0
#     replay_time_ms: 6.062
#     sample_time_ms: 15.55
#     update_time_ms: 0.002
#   iterations_since_restore: 15
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1798681553066614
#     mean_inference_ms: 2.2633232256664946
#     mean_processing_ms: 0.31756703791330293
#   time_since_restore: 90.66580891609192
#   time_this_iter_s: 9.419384956359863
#   time_total_s: 90.66580891609192
#   timestamp: 1575117661
#   timesteps_since_restore: 15000
#   timesteps_this_iter: 1000
#   timesteps_total: 15000
#   training_iteration: 15
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 90 s, 15 iter, 15000 ts, 178 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-11
#   done: false
#   episode_len_mean: 800.75
#   episode_reward_max: 540.0
#   episode_reward_mean: 174.75
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 20
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.038
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.6916255950927734
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 16000
#     num_steps_trained: 48000
#     num_target_updates: 31
#     opt_peak_throughput: 2279.498
#     opt_samples: 32.0
#     replay_time_ms: 5.989
#     sample_time_ms: 15.692
#     update_time_ms: 0.003
#   iterations_since_restore: 16
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1771442358560178
#     mean_inference_ms: 2.2624293239167654
#     mean_processing_ms: 0.3155726278844989
#   time_since_restore: 100.22659635543823
#   time_this_iter_s: 9.560787439346313
#   time_total_s: 100.22659635543823
#   timestamp: 1575117671
#   timesteps_since_restore: 16000
#   timesteps_this_iter: 1000
#   timesteps_total: 16000
#   training_iteration: 16
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 100 s, 16 iter, 16000 ts, 175 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-20
#   done: false
#   episode_len_mean: 802.952380952381
#   episode_reward_max: 540.0
#   episode_reward_mean: 176.42857142857142
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 21
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.416
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.5958824157714844
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 17000
#     num_steps_trained: 56000
#     num_target_updates: 33
#     opt_peak_throughput: 2219.777
#     opt_samples: 32.0
#     replay_time_ms: 5.741
#     sample_time_ms: 18.881
#     update_time_ms: 0.002
#   iterations_since_restore: 17
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1749497716686883
#     mean_inference_ms: 2.2616014380624727
#     mean_processing_ms: 0.31443015872369307
#   time_since_restore: 110.07500743865967
#   time_this_iter_s: 9.848411083221436
#   time_total_s: 110.07500743865967
#   timestamp: 1575117680
#   timesteps_since_restore: 17000
#   timesteps_this_iter: 1000
#   timesteps_total: 17000
#   training_iteration: 17
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 110 s, 17 iter, 17000 ts, 176 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-30
#   done: false
#   episode_len_mean: 796.0
#   episode_reward_max: 540.0
#   episode_reward_mean: 172.6086956521739
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 23
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.144
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.589171886444092
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 18000
#     num_steps_trained: 64000
#     num_target_updates: 35
#     opt_peak_throughput: 2262.479
#     opt_samples: 32.0
#     replay_time_ms: 5.978
#     sample_time_ms: 16.011
#     update_time_ms: 0.002
#   iterations_since_restore: 18
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.170865825425225
#     mean_inference_ms: 2.2599599492813414
#     mean_processing_ms: 0.3121553446393231
#   time_since_restore: 119.49907875061035
#   time_this_iter_s: 9.424071311950684
#   time_total_s: 119.49907875061035
#   timestamp: 1575117690
#   timesteps_since_restore: 18000
#   timesteps_this_iter: 1000
#   timesteps_total: 18000
#   training_iteration: 18
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 119 s, 18 iter, 18000 ts, 173 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-39
#   done: false
#   episode_len_mean: 762.84
#   episode_reward_max: 540.0
#   episode_reward_mean: 163.6
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 25
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.575
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.461317777633667
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 19000
#     num_steps_trained: 72000
#     num_target_updates: 37
#     opt_peak_throughput: 2195.54
#     opt_samples: 32.0
#     replay_time_ms: 6.223
#     sample_time_ms: 15.247
#     update_time_ms: 0.002
#   iterations_since_restore: 19
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1671527854419512
#     mean_inference_ms: 2.258371230554291
#     mean_processing_ms: 0.31007784529403287
#   time_since_restore: 128.83539962768555
#   time_this_iter_s: 9.336320877075195
#   time_total_s: 128.83539962768555
#   timestamp: 1575117699
#   timesteps_since_restore: 19000
#   timesteps_this_iter: 1000
#   timesteps_total: 19000
#   training_iteration: 19
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 128 s, 19 iter, 19000 ts, 164 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-49
#   done: false
#   episode_len_mean: 747.8148148148148
#   episode_reward_max: 540.0
#   episode_reward_mean: 162.22222222222223
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 27
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.219
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.4606878757476807
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 20000
#     num_steps_trained: 80000
#     num_target_updates: 39
#     opt_peak_throughput: 2250.431
#     opt_samples: 32.0
#     replay_time_ms: 5.994
#     sample_time_ms: 15.116
#     update_time_ms: 0.002
#   iterations_since_restore: 20
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.163841915329938
#     mean_inference_ms: 2.256908276338241
#     mean_processing_ms: 0.3081108963233852
#   time_since_restore: 138.2293198108673
#   time_this_iter_s: 9.393920183181763
#   time_total_s: 138.2293198108673
#   timestamp: 1575117709
#   timesteps_since_restore: 20000
#   timesteps_this_iter: 1000
#   timesteps_total: 20000
#   training_iteration: 20
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 138 s, 20 iter, 20000 ts, 162 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-41-58
#   done: false
#   episode_len_mean: 748.2857142857143
#   episode_reward_max: 540.0
#   episode_reward_mean: 160.35714285714286
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 28
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.368
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.3621950149536133
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 21000
#     num_steps_trained: 88000
#     num_target_updates: 41
#     opt_peak_throughput: 2227.174
#     opt_samples: 32.0
#     replay_time_ms: 6.218
#     sample_time_ms: 15.02
#     update_time_ms: 0.002
#   iterations_since_restore: 21
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1622527583110238
#     mean_inference_ms: 2.2562222344904757
#     mean_processing_ms: 0.30713530055434385
#   time_since_restore: 147.6773660182953
#   time_this_iter_s: 9.448046207427979
#   time_total_s: 147.6773660182953
#   timestamp: 1575117718
#   timesteps_since_restore: 21000
#   timesteps_this_iter: 1000
#   timesteps_total: 21000
#   training_iteration: 21
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 147 s, 21 iter, 21000 ts, 160 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-42-08
#   done: false
#   episode_len_mean: 746.5172413793103
#   episode_reward_max: 540.0
#   episode_reward_mean: 158.79310344827587
#   episode_reward_min: 35.0
#   episodes_this_iter: 1
#   episodes_total: 29
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 15.421
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.302034854888916
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 22000
#     num_steps_trained: 96000
#     num_target_updates: 43
#     opt_peak_throughput: 2075.11
#     opt_samples: 32.0
#     replay_time_ms: 6.264
#     sample_time_ms: 15.792
#     update_time_ms: 0.002
#   iterations_since_restore: 22
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1606988220676178
#     mean_inference_ms: 2.2555742119680597
#     mean_processing_ms: 0.3061340111105832
#   time_since_restore: 157.14239835739136
#   time_this_iter_s: 9.46503233909607
#   time_total_s: 157.14239835739136
#   timestamp: 1575117728
#   timesteps_since_restore: 22000
#   timesteps_this_iter: 1000
#   timesteps_total: 22000
#   training_iteration: 22
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 157 s, 22 iter, 22000 ts, 159 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-42-17
#   done: false
#   episode_len_mean: 752.0645161290323
#   episode_reward_max: 540.0
#   episode_reward_mean: 160.6451612903226
#   episode_reward_min: 35.0
#   episodes_this_iter: 2
#   episodes_total: 31
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.216
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.310136318206787
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 23000
#     num_steps_trained: 104000
#     num_target_updates: 45
#     opt_peak_throughput: 2250.944
#     opt_samples: 32.0
#     replay_time_ms: 6.062
#     sample_time_ms: 14.931
#     update_time_ms: 0.002
#   iterations_since_restore: 23
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1578159660726064
#     mean_inference_ms: 2.254402861808466
#     mean_processing_ms: 0.3042414682043826
#   time_since_restore: 166.68359923362732
#   time_this_iter_s: 9.541200876235962
#   time_total_s: 166.68359923362732
#   timestamp: 1575117737
#   timesteps_since_restore: 23000
#   timesteps_this_iter: 1000
#   timesteps_total: 23000
#   training_iteration: 23
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 166 s, 23 iter, 23000 ts, 161 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-42-27
#   done: false
#   episode_len_mean: 740.875
#   episode_reward_max: 540.0
#   episode_reward_mean: 156.25
#   episode_reward_min: 20.0
#   episodes_this_iter: 1
#   episodes_total: 32
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.626
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.2773923873901367
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 24000
#     num_steps_trained: 112000
#     num_target_updates: 47
#     opt_peak_throughput: 2187.895
#     opt_samples: 32.0
#     replay_time_ms: 6.111
#     sample_time_ms: 15.499
#     update_time_ms: 0.002
#   iterations_since_restore: 24
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1564508969831615
#     mean_inference_ms: 2.2538846650241275
#     mean_processing_ms: 0.30330029790905444
#   time_since_restore: 176.13153076171875
#   time_this_iter_s: 9.44793152809143
#   time_total_s: 176.13153076171875
#   timestamp: 1575117747
#   timesteps_since_restore: 24000
#   timesteps_this_iter: 1000
#   timesteps_total: 24000
#   training_iteration: 24
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 176 s, 24 iter, 24000 ts, 156 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-42-36
#   done: false
#   episode_len_mean: 747.9411764705883
#   episode_reward_max: 540.0
#   episode_reward_mean: 158.52941176470588
#   episode_reward_min: 20.0
#   episodes_this_iter: 2
#   episodes_total: 34
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.45
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.222909688949585
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 25000
#     num_steps_trained: 120000
#     num_target_updates: 49
#     opt_peak_throughput: 2214.558
#     opt_samples: 32.0
#     replay_time_ms: 5.823
#     sample_time_ms: 15.46
#     update_time_ms: 0.008
#   iterations_since_restore: 25
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1539093768848174
#     mean_inference_ms: 2.253068203173578
#     mean_processing_ms: 0.30148967016909917
#   time_since_restore: 185.83066129684448
#   time_this_iter_s: 9.699130535125732
#   time_total_s: 185.83066129684448
#   timestamp: 1575117756
#   timesteps_since_restore: 25000
#   timesteps_this_iter: 1000
#   timesteps_total: 25000
#   training_iteration: 25
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.3/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 185 s, 25 iter, 25000 ts, 159 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_12-42-46
#   done: false
#   episode_len_mean: 751.7142857142857
#   episode_reward_max: 540.0
#   episode_reward_mean: 160.0
#   episode_reward_min: 20.0
#   episodes_this_iter: 1
#   episodes_total: 35
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.051
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 3.1710076332092285
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 26000
#     num_steps_trained: 128000
#     num_target_updates: 51
#     opt_peak_throughput: 2277.417
#     opt_samples: 32.0
#     replay_time_ms: 6.372
#     sample_time_ms: 15.278
#     update_time_ms: 0.003
#   iterations_since_restore: 26
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1526884567707183
#     mean_inference_ms: 2.252640684158452
#     mean_processing_ms: 0.3005933306676058
#   time_since_restore: 195.1564908027649
#   time_this_iter_s: 9.32582950592041
#   time_total_s: 195.1564908027649
#   timestamp: 1575117766
#   timesteps_since_restore: 26000
# ...
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10586 s, 814 iter, 814000 ts, 279 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-36-22
#   done: false
#   episode_len_mean: 771.87
#   episode_reward_max: 800.0
#   episode_reward_mean: 274.35
#   episode_reward_min: 30.0
#   episodes_this_iter: 1
#   episodes_total: 1071
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 13.73
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.2429614067077637
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 815000
#     num_steps_trained: 6440000
#     num_target_updates: 1617
#     opt_peak_throughput: 2330.582
#     opt_samples: 32.0
#     replay_time_ms: 6.026
#     sample_time_ms: 14.939
#     update_time_ms: 0.003
#   iterations_since_restore: 815
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1026046330759052
#     mean_inference_ms: 2.2977894212532934
#     mean_processing_ms: 0.2504592444411665
#   time_since_restore: 10602.230459928513
#   time_this_iter_s: 16.00782799720764
#   time_total_s: 10602.230459928513
#   timestamp: 1575128182
#   timesteps_since_restore: 815000
#   timesteps_this_iter: 1000
#   timesteps_total: 815000
#   training_iteration: 815
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10602 s, 815 iter, 815000 ts, 274 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-36-38
#   done: false
#   episode_len_mean: 773.77
#   episode_reward_max: 800.0
#   episode_reward_mean: 275.8
#   episode_reward_min: 30.0
#   episodes_this_iter: 2
#   episodes_total: 1073
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.589
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.250559091567993
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 816000
#     num_steps_trained: 6448000
#     num_target_updates: 1619
#     opt_peak_throughput: 2193.405
#     opt_samples: 32.0
#     replay_time_ms: 5.887
#     sample_time_ms: 14.794
#     update_time_ms: 0.003
#   iterations_since_restore: 816
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1024959240386476
#     mean_inference_ms: 2.2976165377244344
#     mean_processing_ms: 0.2504254335207302
#   time_since_restore: 10618.132405996323
#   time_this_iter_s: 15.901946067810059
#   time_total_s: 10618.132405996323
#   timestamp: 1575128198
#   timesteps_since_restore: 816000
#   timesteps_this_iter: 1000
#   timesteps_total: 816000
#   training_iteration: 816
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10618 s, 816 iter, 816000 ts, 276 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-36-54
#   done: false
#   episode_len_mean: 773.77
#   episode_reward_max: 800.0
#   episode_reward_mean: 275.4
#   episode_reward_min: 30.0
#   episodes_this_iter: 1
#   episodes_total: 1074
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.449
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.2724132537841797
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 817000
#     num_steps_trained: 6456000
#     num_target_updates: 1621
#     opt_peak_throughput: 2214.73
#     opt_samples: 32.0
#     replay_time_ms: 5.943
#     sample_time_ms: 15.675
#     update_time_ms: 0.004
#   iterations_since_restore: 817
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.102441529551342
#     mean_inference_ms: 2.2975300189999315
#     mean_processing_ms: 0.25040848341773836
#   time_since_restore: 10634.267055511475
#   time_this_iter_s: 16.134649515151978
#   time_total_s: 10634.267055511475
#   timestamp: 1575128214
#   timesteps_since_restore: 817000
#   timesteps_this_iter: 1000
#   timesteps_total: 817000
#   training_iteration: 817
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10634 s, 817 iter, 817000 ts, 275 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-37-10
#   done: false
#   episode_len_mean: 774.09
#   episode_reward_max: 800.0
#   episode_reward_mean: 276.0
#   episode_reward_min: 30.0
#   episodes_this_iter: 2
#   episodes_total: 1076
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.164
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.1990365982055664
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 818000
#     num_steps_trained: 6464000
#     num_target_updates: 1623
#     opt_peak_throughput: 2259.196
#     opt_samples: 32.0
#     replay_time_ms: 6.11
#     sample_time_ms: 14.876
#     update_time_ms: 0.003
#   iterations_since_restore: 818
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1023329451028046
#     mean_inference_ms: 2.297356705310774
#     mean_processing_ms: 0.2503747367354255
#   time_since_restore: 10650.277899980545
#   time_this_iter_s: 16.010844469070435
#   time_total_s: 10650.277899980545
#   timestamp: 1575128230
#   timesteps_since_restore: 818000
#   timesteps_this_iter: 1000
#   timesteps_total: 818000
#   training_iteration: 818
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10650 s, 818 iter, 818000 ts, 276 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-37-26
#   done: false
#   episode_len_mean: 774.04
#   episode_reward_max: 800.0
#   episode_reward_mean: 276.2
#   episode_reward_min: 30.0
#   episodes_this_iter: 1
#   episodes_total: 1077
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.045
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.2103567123413086
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 819000
#     num_steps_trained: 6472000
#     num_target_updates: 1625
#     opt_peak_throughput: 2278.337
#     opt_samples: 32.0
#     replay_time_ms: 5.828
#     sample_time_ms: 14.937
#     update_time_ms: 0.002
#   iterations_since_restore: 819
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1022786487853509
#     mean_inference_ms: 2.2972690335267183
#     mean_processing_ms: 0.2503576216048407
#   time_since_restore: 10666.202559709549
#   time_this_iter_s: 15.924659729003906
#   time_total_s: 10666.202559709549
#   timestamp: 1575128246
#   timesteps_since_restore: 819000
#   timesteps_this_iter: 1000
#   timesteps_total: 819000
#   training_iteration: 819
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10666 s, 819 iter, 819000 ts, 276 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-37-38
#   done: false
#   episode_len_mean: 773.87
#   episode_reward_max: 800.0
#   episode_reward_mean: 276.1
#   episode_reward_min: 30.0
#   episodes_this_iter: 2
#   episodes_total: 1079
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.978
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.2269606590270996
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 820000
#     num_steps_trained: 6480000
#     num_target_updates: 1626
#     opt_peak_throughput: 2136.466
#     opt_samples: 32.0
#     replay_time_ms: 5.749
#     sample_time_ms: 15.032
#     update_time_ms: 0.004
#   iterations_since_restore: 820
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1021704217639694
#     mean_inference_ms: 2.2970936772926818
#     mean_processing_ms: 0.25032323426741715
#   time_since_restore: 10678.692090034485
#   time_this_iter_s: 12.489530324935913
#   time_total_s: 10678.692090034485
#   timestamp: 1575128258
#   timesteps_since_restore: 820000
#   timesteps_this_iter: 1000
#   timesteps_total: 820000
#   training_iteration: 820
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10678 s, 820 iter, 820000 ts, 276 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-37-55
#   done: false
#   episode_len_mean: 775.3
#   episode_reward_max: 800.0
#   episode_reward_mean: 276.45
#   episode_reward_min: 30.0
#   episodes_this_iter: 1
#   episodes_total: 1080
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.848
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.207714080810547
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 821000
#     num_steps_trained: 6488000
#     num_target_updates: 1628
#     opt_peak_throughput: 2155.108
#     opt_samples: 32.0
#     replay_time_ms: 5.652
#     sample_time_ms: 14.699
#     update_time_ms: 0.002
#   iterations_since_restore: 821
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1021162056506053
#     mean_inference_ms: 2.297005813308649
#     mean_processing_ms: 0.25030637103343556
#   time_since_restore: 10694.732063055038
#   time_this_iter_s: 16.03997302055359
#   time_total_s: 10694.732063055038
#   timestamp: 1575128275
#   timesteps_since_restore: 821000
#   timesteps_this_iter: 1000
#   timesteps_total: 821000
#   training_iteration: 821
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10694 s, 821 iter, 821000 ts, 276 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-38-11
#   done: false
#   episode_len_mean: 764.33
#   episode_reward_max: 800.0
#   episode_reward_mean: 272.15
#   episode_reward_min: 30.0
#   episodes_this_iter: 2
#   episodes_total: 1082
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 14.168
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.2616255283355713
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 822000
#     num_steps_trained: 6496000
#     num_target_updates: 1630
#     opt_peak_throughput: 2258.607
#     opt_samples: 32.0
#     replay_time_ms: 6.517
#     sample_time_ms: 14.788
#     update_time_ms: 0.004
#   iterations_since_restore: 822
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.1020082680534713
#     mean_inference_ms: 2.29683137424372
#     mean_processing_ms: 0.25027324061959094
#   time_since_restore: 10710.740254163742
#   time_this_iter_s: 16.008191108703613
#   time_total_s: 10710.740254163742
#   timestamp: 1575128291
#   timesteps_since_restore: 822000
#   timesteps_this_iter: 1000
#   timesteps_total: 822000
#   training_iteration: 822
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10710 s, 822 iter, 822000 ts, 272 rew
#
# Result for DQN_SpaceInvaders-v0_0:
#   custom_metrics: {}
#   date: 2019-11-30_15-38-27
#   done: false
#   episode_len_mean: 759.89
#   episode_reward_max: 800.0
#   episode_reward_mean: 272.65
#   episode_reward_min: 30.0
#   episodes_this_iter: 1
#   episodes_total: 1083
#   experiment_id: df5efe80fc3f4c7a82dc6523326c71ea
#   hostname: 3214eeb989f5
#   info:
#     grad_time_ms: 15.746
#     learner:
#       default_policy:
#         cur_lr: 9.999999747378752e-05
#         mean_td_error: 2.3031697273254395
#         model: {}
#     max_exploration: 0.0
#     min_exploration: 0.0
#     num_steps_sampled: 823000
#     num_steps_trained: 6504000
#     num_target_updates: 1632
#     opt_peak_throughput: 2032.241
#     opt_samples: 32.0
#     replay_time_ms: 6.544
#     sample_time_ms: 15.281
#     update_time_ms: 0.002
#   iterations_since_restore: 823
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   pid: 877
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 1.101954490964175
#     mean_inference_ms: 2.296744891184678
#     mean_processing_ms: 0.25025712313304477
#   time_since_restore: 10726.833067893982
#   time_this_iter_s: 16.092813730239868
#   time_total_s: 10726.833067893982
#   timestamp: 1575128307
#   timesteps_since_restore: 823000
#   timesteps_this_iter: 1000
#   timesteps_total: 823000
#   training_iteration: 823
#   trial_id: 6b155e90
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 1/2 CPUs, 1/1 GPUs, 0.0/5.42 GiB heap, 0.0/1.86 GiB objects
# Memory usage on this node: 3.4/12.7 GiB
# Result logdir: /root/ray_results/default
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - DQN_SpaceInvaders-v0_0:	RUNNING, [1 CPUs, 1 GPUs], [pid=877], 10726 s, 823 iter, 823000 ts, 273 rew
#
# ^C

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2019-11-30 15:40:46--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.54.249.116, 52.86.175.38, 34.230.145.192, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.54.249.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  14.6MB/s    in 0.9s
#
# 2019-11-30 15:40:47 (14.6 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = '~/ray_results'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://9f29f40e.ngrok.io

# %%
# !tensorboard --logdir=~/ray_results
# Out:
# TensorBoard 1.15.0 at http://3214eeb989f5:6006/ (Press CTRL+C to quit)
# ^C
